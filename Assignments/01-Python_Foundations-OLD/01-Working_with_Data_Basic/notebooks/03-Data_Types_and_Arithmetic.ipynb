# %% [markdown]
# ## Rykir Evans Submission

# %% [markdown]
# # 📘 03 - Data Types and Arithmetic
#
# Explore Python basics like variables, data types, and arithmetic operations.

# %% [markdown]
# ## ✅ Learning Goals
# - Understand Python data types
# - Use variables and print statements
# - Perform basic arithmetic

# %%
# 🧠 Variables and Types
x = 10
y = 3.5
z = 'hello'
print(type(x), type(y), type(z))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
# ➕ Arithmetic Operations
print('Add:', x + y)
print('Divide:', x / y)
print('Floor Divide:', x // y)
print('Exponent:', x ** 2)

# %% [markdown]
# ## ✏️ Try It Yourself
# - Create your own variables
# - Try combining numbers and strings
# - Use `input()` to interact

# %%
# Your code here
name = input('What is your name? ')
print('Welcome,', name)

grad = int(input("When did you or will you graduate with your bachelor's?"))
if grad <= 2025:
    print("You're an Old head")
else:
    print("You're a young Whipper Snapper")

pet_name = input("What is the name of your pet?")
print(f"Wow, {pet_name} is a great name, very original...")

print("Goodbye!")
# Out:
# Welcome, R
# You're a young Whipper Snapper
# Wow, Beef is a great name, very original...

# %% [markdown]
# ## 📤 Submit
# Make sure your name is at the top in a Markdown cell.
# Submit via D2L or Colab link.
