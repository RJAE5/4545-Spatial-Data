# %% [markdown]
# # 🧼 Cleaning Dirty Data (Missing Values & Type Fixes)
#
# ## 🔹 LEARNING GOALS:
# - Detect and count missing values (`NaN`)
# - Fill or drop missing data
# - Convert column data types safely
# - Understand the difference between `NaN`, `None`, `""`, and type mismatches

# %% [markdown]
# ### 🧪 1. Load a Messy Dataset

# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", None],
    "Age": ["25", "thirty", 35, np.nan, "40"],
    "Signup Date": ["2022-01-01", "not a date", "2022/03/01", None, "April 5, 2022"],
    "Score": [95.5, None, 88.0, 92.5, ""]
}

df = pd.DataFrame(data)
df
# Out:
#       Name     Age    Signup Date Score
# 0    Alice      25     2022-01-01  95.5
# 1      Bob  thirty     not a date  None
# 2  Charlie      35     2022/03/01  88.0
# 3    David     NaN            NaN  92.5
# 4      NaN      40  April 5, 2022

# %% [markdown]
# ### 🧯 2. Detecting Missing or Broken Values

# %%
df.isnull()
# Out:
#     Name    Age  Signup Date  Score
# 0  False  False        False  False
# 1  False  False        False   True
# 2  False  False        False  False
# 3  False   True         True  False
# 4   True  False        False  False

# %%
df.isnull().sum()
# Out:
# Name           1
# Age            1
# Signup Date    1
# Score          1
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Name     Age    Signup Date Score
# 1    Bob  thirty     not a date  None
# 3  David     NaN            NaN  92.5
# 4    NaN      40  April 5, 2022

# %% [markdown]
# ### 🧹 3. Cleaning Strategy Options

# %%
df.fillna({
    "Name": "Unknown",
    "Age": -1,
    "Signup Date": "1970-01-01",
    "Score": 0.0
})
# Out:
#       Name     Age    Signup Date Score
# 0    Alice      25     2022-01-01  95.5
# 1      Bob  thirty     not a date   0.0
# 2  Charlie      35     2022/03/01  88.0
# 3    David      -1     1970-01-01  92.5
# 4  Unknown      40  April 5, 2022

# %%
df.dropna()
# Out:
#       Name Age Signup Date Score
# 0    Alice  25  2022-01-01  95.5
# 2  Charlie  35  2022/03/01  88.0

# %% [markdown]
# ### 🧬 4. Data Type Fixes

# %%
df.dtypes
# Out:
# Name              str
# Age            object
# Signup Date       str
# Score          object
# dtype: object

# %%
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")
df["Score"] = pd.to_numeric(df["Score"], errors="coerce")
df["Signup Date"] = pd.to_datetime(df["Signup Date"], errors="coerce")
df.dtypes
# Out:
# Name                      str
# Age                   float64
# Signup Date    datetime64[us]
# Score                 float64
# dtype: object

# %% [markdown]
# ### 🩹 5. Impute (Fill In) Fixed Missing Values

# %%
df["Age"].fillna(df["Age"].median(), inplace=True)
df["Score"].fillna(df["Score"].mean(), inplace=True)
# Out:
# /tmp/ipykernel_88994/1713118361.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Age"].fillna(df["Age"].median(), inplace=True)
# /tmp/ipykernel_88994/1713118361.py:2: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Score"].fillna(df["Score"].mean(), inplace=True)
# 0    95.5
# 1    92.0
# 2    88.0
# 3    92.5
# 4    92.0
# Name: Score, dtype: float64

# %%
df["Signup Date"].fillna(df["Signup Date"].min(), inplace=True)
# Out:
# /tmp/ipykernel_88994/3000949103.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Signup Date"].fillna(df["Signup Date"].min(), inplace=True)
# 0   2022-01-01
# 1   2022-01-01
# 2   2022-01-01
# 3   2022-01-01
# 4   2022-01-01
# Name: Signup Date, dtype: datetime64[us]

# %%
df["Name"].fillna("Unknown", inplace=True)
# Out:
# /tmp/ipykernel_88994/626038248.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   df["Name"].fillna("Unknown", inplace=True)
# 0      Alice
# 1        Bob
# 2    Charlie
# 3      David
# 4    Unknown
# Name: Name, dtype: str

# %% [markdown]
# ### 🤓 6. Cleaned Data Review

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         4 non-null      str
#  1   Age          3 non-null      float64
#  2   Signup Date  1 non-null      datetime64[us]
#  3   Score        3 non-null      float64
# dtypes: datetime64[us](1), float64(2), str(1)
# memory usage: 292.0 bytes

# %%
df.describe(include="all")
# Out:
#          Name        Age          Signup Date      Score
# count       4   3.000000                    1   3.000000
# unique      4        NaN                  NaN        NaN
# top     Alice        NaN                  NaN        NaN
# freq        1        NaN                  NaN        NaN
# mean      NaN  33.333333  2022-01-01 00:00:00  92.000000
# min       NaN  25.000000  2022-01-01 00:00:00  88.000000
# 25%       NaN  30.000000  2022-01-01 00:00:00  90.250000
# 50%       NaN  35.000000  2022-01-01 00:00:00  92.500000
# 75%       NaN  37.500000  2022-01-01 00:00:00  94.000000
# max       NaN  40.000000  2022-01-01 00:00:00  95.500000
# std       NaN   7.637626                  NaN   3.774917

# %% [markdown]
# ### 🧪 Try It Yourself
#
# Modify the `data` dictionary at the top of this notebook. Add:
# - A new column with some `None` and `""` values
# - At least one row with all columns filled incorrectly
# Then re-run the notebook and fix it step-by-step.

# %%
import pandas as pd
import numpy as np

data = {
    "Name": ["Alice", "Bob", "Charlie", "David", None, "Eve"],
    "Age": ["25", "thirty", 35, np.nan, "40", "unknown"],
    "Signup Date": ["2022-01-01", "not a date", "2022/03/01", None, "April 5, 2022", ""],
    "Score": [95.5, None, 88.0, 92.5, "", "bad"],
    "Status": ["active", "", None, "inactive", "active", None]
}

df = pd.DataFrame(data)

df = df.replace(["", " ", "bad", "unknown"], np.nan)

df["Age"] = pd.to_numeric(df["Age"], errors="coerce")
df["Score"] = pd.to_numeric(df["Score"], errors="coerce")

df["Signup Date"] = pd.to_datetime(df["Signup Date"], errors="coerce")

df["Name"] = df["Name"].fillna("Unknown")
df["Status"] = df["Status"].fillna("unknown")

print(df.info())
print(df)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         6 non-null      str
#  1   Age          3 non-null      float64
#  2   Signup Date  1 non-null      datetime64[us]
#  3   Score        3 non-null      float64
#  4   Status       6 non-null      str
# dtypes: datetime64[us](1), float64(2), str(2)
# memory usage: 372.0 bytes
# None
#       Name   Age Signup Date  Score    Status
# 0    Alice  25.0  2022-01-01   95.5    active
# 1      Bob   NaN         NaT    NaN   unknown
# 2  Charlie  35.0         NaT   88.0   unknown
# 3    David   NaN         NaT   92.5  inactive
# 4  Unknown  40.0         NaT    NaN    active
# 5      Eve   NaN         NaT    NaN   unknown

# %% [markdown]
# ### 🧠 Mini-Challenge
#
# > 🗂 Load `"data/survey.csv"` and:
# - Identify which columns have missing values
# - Use `.isnull().sum()` to get a null report
# - Use a mix of `.fillna()`, `.dropna()`, and `pd.to_numeric()` or `pd.to_datetime()` to clean it
# - Print a summary with `.info()` and `.describe()`

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("../../data/survey.csv")

print(df.isnull().sum())

for col in df.columns:
    if df[col].dtype == "object":
        df[col] = df[col].replace(["", " ", "NA", "na", "N/A"], np.nan)

for col in df.columns:
    if df[col].dtype == "object":
        try:
            df[col] = pd.to_numeric(df[col])
        except:
            pass

for col in df.columns:
    if "date" in col.lower():
        df[col] = pd.to_datetime(df[col], errors="coerce")

df = df.dropna(thresh=int(0.5 * len(df.columns)))

df = df.fillna(df.median(numeric_only=True))

print(df.info())
print(df.describe())
# Out:
# student_id               0
# age                     33
# gender                  23
# major                   10
# gpa                     44
# study_hours_per_week    42
# satisfaction_1_5        46
# survey_date             32
# dorm_resident           33
# expected_grad_year      33
# income_range            21
# commute_minutes         53
# clubs_member            25
# attendance_rate         79
# favorite_language       19
# comments                52
# dtype: int64
# <class 'pandas.DataFrame'>
# Index: 118 entries, 0 to 118
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   student_id            118 non-null    str
#  1   age                   85 non-null     str
#  2   gender                96 non-null     str
#  3   major                 110 non-null    str
#  4   gpa                   76 non-null     str
#  5   study_hours_per_week  78 non-null     str
#  6   satisfaction_1_5      73 non-null     str
#  7   survey_date           60 non-null     datetime64[us]
#  8   dorm_resident         85 non-null     str
#  9   expected_grad_year    85 non-null     str
#  10  income_range          98 non-null     str
#  11  commute_minutes       67 non-null     str
#  12  clubs_member          95 non-null     str
#  13  attendance_rate       41 non-null     str
#  14  favorite_language     100 non-null    str
#  15  comments              67 non-null     str
# dtypes: datetime64[us](1), str(15)
# memory usage: 15.7 KB
# None
#                survey_date
# count                   60
# mean   2025-10-20 06:48:00
# min    2025-09-02 00:00:00
# 25%    2025-10-01 18:00:00
# 50%    2025-10-25 12:00:00
# 75%    2025-11-08 00:00:00
# max    2025-11-30 00:00:00
# /tmp/ipykernel_88994/2431402979.py:21: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df[col] = pd.to_datetime(df[col], errors="coerce")

# %% [markdown]
# ### 📝 Summary
#
# | Concept        | Tool/Function                      |
# |----------------|------------------------------------|
# | Detect nulls   | `df.isnull()`, `df.isnull().sum()` |
# | Drop rows      | `df.dropna()`                      |
# | Fill values    | `df.fillna()`                      |
# | Convert types  | `pd.to_numeric()`, `pd.to_datetime()` |
# | Replace values | `df.replace()`                     |
